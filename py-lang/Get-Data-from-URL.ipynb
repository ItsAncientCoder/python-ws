# %%
import pandas as pd
from urllib.request import urlretrieve
url = 'https://s3.amazonaws.com/assets.datacamp.com/production/course_1606/datasets/winequality-red.csv'
urlretrieve(url, 'C:\\Users\\ac29019\\Music\\python\\data.csv')
# Out:
# ('C:\\Users\\ac29019\\Music\\python\\data.csv',
#  <http.client.HTTPMessage at 0x246d88650b8>)

# %%
df = pd.read_csv('C:\\Users\\ac29019\\Music\\python\\data.csv', sep = ';')
t = df.iloc[:,0]
import matplotlib.pyplot as plt
plt.plot(t)
plt.show()
