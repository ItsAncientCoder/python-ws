# %%
import pandas as pd

# %%
file = 'ebola_data_db_format.xlsx'
df = pd.read_excel(file, index_col=False, sheet_name='ebola_data_db_format')
#df.sample(10)
#df.Country.values

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)
df['Country'] = df['Country'].replace('Nigeria', 'India')
#df.sample(10)

# %%
#df.notnull().all().all()

# %%
#df1 = df.pivot_table(index=['Indicator'], columns='Country', values='value')
#df1.sample(10)

# %%
import glob
all_file_names = glob.glob('*')
#all_file_names

# %%
df_with_nan = pd.read_excel(file, na_values={'value':['0'],'Country':['Mali']}, 
                            index_col=False, sheet_name='ebola_data_db_format')
df_with_nan.iloc[20:40,:]
# Out:
#                                             Indicator         Country  \
# 20         Cumulative number of confirmed Ebola cases  United Kingdom
# 21          Cumulative number of probable Ebola cases  United Kingdom
# 22         Cumulative number of suspected Ebola cases  United Kingdom
# 23  Cumulative number of confirmed, probable and s...  United Kingdom
# 24  Cumulative number of confirmed, probable and s...  United Kingdom
# 25         Cumulative number of confirmed Ebola cases             NaN
# 26          Cumulative number of probable Ebola cases             NaN
# 27         Cumulative number of suspected Ebola cases             NaN
# 28  Cumulative number of confirmed, probable and s...             NaN
# 29  Cumulative number of confirmed, probable and s...             NaN
# 30         Cumulative number of confirmed Ebola cases         Nigeria
# 31          Cumulative number of probable Ebola cases         Nigeria
# ...

# %%
help(pd.read_excel)
# Out:
# Help on function read_excel in module pandas.io.excel:
#
# read_excel(io, sheet_name=0, header=0, names=None, index_col=None, parse_cols=None, usecols=None, squeeze=False, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skiprows=None, nrows=None, na_values=None, keep_default_na=True, verbose=False, parse_dates=False, date_parser=None, thousands=None, comment=None, skip_footer=0, skipfooter=0, convert_float=True, mangle_dupe_cols=True, **kwds)
#     Read an Excel file into a pandas DataFrame.
#
#     Support both `xls` and `xlsx` file extensions from a local filesystem or URL.
#     Support an option to read a single sheet or a list of sheets.
#
#     Parameters
#     ----------
#     io : str, file descriptor, pathlib.Path, ExcelFile or xlrd.Book
#         The string could be a URL. Valid URL schemes include http, ftp, s3,
#         gcs, and file. For file URLs, a host is expected. For instance, a local
#         file could be /path/to/workbook.xlsx.
# ...
